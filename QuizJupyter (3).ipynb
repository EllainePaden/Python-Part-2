# %%
#Introduction to the Quiz

def Introduction():
   name = input('Kindly Enter your Name: ')
   print("Hello" + "\t" + name.title() + "!" + "\nWelcome to the Planetary Quiz" + "\nChoose the Correct Answer to the following questions.")


#quiz proper

def Quiz():
  questions = ['\n1. How many planets are there in the Solar System? \nA. 3 \tB. 9\n',
              '\n2. What planet is closest to the sun? \nA. Mars \tB. Mercury\n',
              '\n3. Which is the coldest planet of the Solar System? \nA. Pluto \tB. Saturn\n',
              '\n4. Which is the densest planet? \nA. Earth \tB. Jupiter\n',
              '\n5. Which planet is not a terrestial planet \nA. Saturn \tB. Mars\n',
              '\n6. What is the eight planet from the sun? \nA. Neptune \tB. Jupiter\n',
              '\n7. Which planet has the largest ring system? \nA. Saturn \tB. Jupiter\n',
              '\n8. What is the rotational period of Earth? \nA. 24 hours \tB. 36 hours\n',
              '\n9. Which is shorter, Mercury  day or year? \nA. Day \tB. Year\n',
              '\n10. Which planet has the hottest temperature? \nA. Venus \tB. Mars\n'
              ]
  answers = ['B','B','A','A','A','A','A','A','B','A']

  score = 0
  a = 0
  
  for question in questions:
    print(question)

    ans = input("Kindly Enter your Answer: ")

    if ans.upper() == answers[a]:
      print("\nYou are correct!\n")
      score +=1
    else:
      print("\nSorry, you got it wrong\n")

    a +=1

  print("\nYour Final Score is:{0} out of 10".format(score))
  
  if score < 6:
    print("\nBetter luck next time =(")
  else:
    print("\nGood job! =)")

Introduction()
Quiz()
# Out:
# Kindly Enter your Name: Ellaine
# Hello	Ellaine!
# Welcome to the Planetary Quiz
# Choose the Correct Answer to the following questions.
#
# 1. How many planets are there in the Solar System?
# A. 3 	B. 9
#
# Kindly Enter your Answer: a
#
# Sorry, you got it wrong
#
#
# 2. What planet is closest to the sun?
# A. Mars 	B. Mercury
#
# Kindly Enter your Answer:
#
# Sorry, you got it wrong
#
#
# 3. Which is the coldest planet of the Solar System?
# A. Pluto 	B. Saturn
#
# Kindly Enter your Answer: a
# Kindly Enter your Answer:
#
# You are correct!
#
#
# 4. Which is the densest planet?
# A. Earth 	B. Jupiter
#
#
# Sorry, you got it wrong
#
#
# 5. Which planet is not a terrestial planet
# A. Saturn 	B. Mars
#
# Kindly Enter your Answer: b
# Kindly Enter your Answer:
#
# Sorry, you got it wrong
#
#
# 6. What is the eight planet from the sun?
# A. Neptune 	B. Jupiter
#
#
# Sorry, you got it wrong
#
#
# 7. Which planet has the largest ring system?
# A. Saturn 	B. Jupiter
#
# Kindly Enter your Answer:
# Kindly Enter your Answer:
#
# Sorry, you got it wrong
#
#
# 8. What is the rotational period of Earth?
# A. 24 hours 	B. 36 hours
#
#
# Sorry, you got it wrong
#
#
# 9. Which is shorter, Mercury  day or year?
# A. Day 	B. Year
#
# Kindly Enter your Answer: b
#
# You are correct!
#
#
# 10. Which planet has the hottest temperature?
# A. Venus 	B. Mars
#
# Kindly Enter your Answer: b
#
# Sorry, you got it wrong
#
#
# Your Final Score is:2 out of 10
#
# Better luck next time =(

# %%
#Introduction to the Quiz

def Introduction():
   Introduction.name = input('Kindly Enter your Name: ')
   print("Hello" + "\t" + Introduction.name.title() + "!" + "\nWelcome to the Planetary Quiz" + "\nChoose the Correct Answer to the following questions.")


#quiz proper

def Quiz():
  questions = ['\n1. How many planets are there in the Solar System? \nA. 3 \tB. 9\n',
              '\n2. What planet is closest to the sun? \nA. Mars \tB. Mercury\n',
              '\n3. Which is the coldest planet of the Solar System? \nA. Pluto \tB. Saturn\n',
              '\n4. Which is the densest planet? \nA. Earth \tB. Jupiter\n',
              '\n5. Which planet is not a terrestial planet \nA. Saturn \tB. Mars\n',
              '\n6. What is the eight planet from the sun? \nA. Neptune \tB. Jupiter\n',
              '\n7. Which planet has the largest ring system? \nA. Saturn \tB. Jupiter\n',
              '\n8. What is the rotational period of Earth? \nA. 24 hours \tB. 36 hours\n',
              '\n9. Which is shorter, Mercury  day or year? \nA. Day \tB. Year\n',
              '\n10. Which planet has the hottest temperature? \nA. Venus \tB. Mars\n'
              ]
  answers = ['B','B','A','A','A','A','A','A','B','A']

  Quiz.score = 0
  a = 0
  
  for question in questions:
    print(question)

    ans = input("Kindly Enter your Answer: ")

    if ans.upper() == answers[a]:
      print("\nYou are correct!\n")
      Quiz.score +=1
    else:
      print("\nSorry, you got it wrong\n")

    a +=1

  print("\nYour Final Score is:{0} out of 10".format(Quiz.score))

   
  if Quiz.score < 6:
    print("\nBetter luck next time =(")
  else:
    print("\nGood job! =)")

class Player ():
   def __init__(self,name,score):
        self.name = name
        self.score = score        

players = []
r ='Y'
while r != 'N':
  Introduction()
  Quiz()
  P1 = Player(Introduction.name,Quiz.score)
  q = input("Do you want to play another game? (Y/N): ")
  r = q.upper()
  players.append(P1)

print('\n')

file1 = open("results.txt","w") 
for user in players: 
  #print("Player Name:{0} | Score:{1}".format(user.name,user.score))
  file1.write("Player Name:{0} | Score:{1}\n".format(user.name,user.score))
file1.close()

file1 = open("results.txt","r")  
  
text = file1.read() 
#file1.readlines() to read a list of text

print(text)


  
print("\nGoodbye! Thanks for playing =)")
# Out:
# Kindly Enter your Name: Ellaine
# Hello	Ellaine!
# Welcome to the Planetary Quiz
# Choose the Correct Answer to the following questions.
#
# 1. How many planets are there in the Solar System?
# A. 3 	B. 9
#
# Kindly Enter your Answer: a
#
# Sorry, you got it wrong
#
#
# 2. What planet is closest to the sun?
# A. Mars 	B. Mercury
#
# Kindly Enter your Answer: b
#
# You are correct!
#
#
# 3. Which is the coldest planet of the Solar System?
# A. Pluto 	B. Saturn
#
# Kindly Enter your Answer: a
#
# You are correct!
#
#
# 4. Which is the densest planet?
# A. Earth 	B. Jupiter
#
# Kindly Enter your Answer: a
#
# You are correct!
#
#
# 5. Which planet is not a terrestial planet
# A. Saturn 	B. Mars
#
# Kindly Enter your Answer:
#
# Sorry, you got it wrong
#
#
# 6. What is the eight planet from the sun?
# A. Neptune 	B. Jupiter
#
# Kindly Enter your Answer:
#
# Sorry, you got it wrong
#
#
# 7. Which planet has the largest ring system?
# A. Saturn 	B. Jupiter
#
# Kindly Enter your Answer:
# Kindly Enter your Answer:
#
# Sorry, you got it wrong
#
#
# 8. What is the rotational period of Earth?
# A. 24 hours 	B. 36 hours
#
#
# Sorry, you got it wrong
#
#
# 9. Which is shorter, Mercury  day or year?
# A. Day 	B. Year
#
# Kindly Enter your Answer: a
#
# Sorry, you got it wrong
#
#
# 10. Which planet has the hottest temperature?
# A. Venus 	B. Mars
#
# Kindly Enter your Answer: a
#
# You are correct!
#
#
# Your Final Score is:4 out of 10
#
# Better luck next time =(
# Do you want to play another game? (Y/N): Y
# Kindly Enter your Name: Beborn
# Hello	Beborn!
# Welcome to the Planetary Quiz
# Choose the Correct Answer to the following questions.
#
# 1. How many planets are there in the Solar System?
# A. 3 	B. 9
#
# Kindly Enter your Answer: a
#
# Sorry, you got it wrong
#
#
# 2. What planet is closest to the sun?
# A. Mars 	B. Mercury
#
# Kindly Enter your Answer: a
#
# Sorry, you got it wrong
#
#
# 3. Which is the coldest planet of the Solar System?
# A. Pluto 	B. Saturn
#
# Kindly Enter your Answer:
#
# Sorry, you got it wrong
#
#
# 4. Which is the densest planet?
# A. Earth 	B. Jupiter
#
# Kindly Enter your Answer:
# Kindly Enter your Answer: b
#
# Sorry, you got it wrong
#
#
# 5. Which planet is not a terrestial planet
# A. Saturn 	B. Mars
#
#
# Sorry, you got it wrong
#
#
# 6. What is the eight planet from the sun?
# A. Neptune 	B. Jupiter
#
# Kindly Enter your Answer: b
# Kindly Enter your Answer:
#
# Sorry, you got it wrong
#
#
# 7. Which planet has the largest ring system?
# A. Saturn 	B. Jupiter
#
#
# Sorry, you got it wrong
#
#
# 8. What is the rotational period of Earth?
# A. 24 hours 	B. 36 hours
#
# Kindly Enter your Answer:
# Kindly Enter your Answer: a
#
# Sorry, you got it wrong
#
#
# 9. Which is shorter, Mercury  day or year?
# A. Day 	B. Year
#
#
# Sorry, you got it wrong
#
#
# 10. Which planet has the hottest temperature?
# A. Venus 	B. Mars
#
# Kindly Enter your Answer: b
#
# Sorry, you got it wrong
#
#
# Your Final Score is:0 out of 10
#
# Better luck next time =(
# Do you want to play another game? (Y/N): n
#
#
# Player Name:Ellaine | Score:4
# Player Name:Beborn | Score:0
#
#
# Goodbye! Thanks for playing =)

# %%
csv_text_list = []
  for row in csv_text:
    csv_text_list.append(row.split(","))
    
csv_text_list

  for row in csv_text_list:
    tmp_text = ",".join(row)
    print(tmp_text)

file1 = open("highscore.csv","a") # use 'a' for appending to a file

text_list = []
  for row in csv_text_list:
    tmp_text = ",".join(row)
    text_list.append(tmp_text+"\n")
file1.writelines(text_list)
file1.close()

file1 = open("high score.csv","r")  
  
text = file1.readlines() 
print(text)

  for row in text:
    for col in row.split(","):
        print(col.strip() , end = " ")
    print("")
