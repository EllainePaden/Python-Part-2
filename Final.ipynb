# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4985d706-5ffa-4471-90bf-bb0a813af9a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4985d706-5ffa-4471-90bf-bb0a813af9a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving insurance_regression (1).csv to insurance_regression (1).csv
# ...

# %%
import pandas as pd

df = pd.read_csv('insurance_regression (1).csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df['charges'].mean()
# Out:
# 13270.422265141257

# %%
df['charges'].max()
# Out:
# 63770.42801

# %%
df['charges'].min()
# Out:
# 1121.8739

# %%
df['sex'].count()
# Out:
# 1338

# %%
df[['sex','smoker']].groupby("sex").agg("count")
# Out:
#         smoker
# sex
# female     662
# male       676

# %%
df[['smoker','charges']].groupby(['smoker']).agg(["mean","max","min"])
# Out:
#              charges
#                 mean          max         min
# smoker
# no       8434.268298  36910.60803   1121.8739
# yes     32050.231832  63770.42801  12829.4551

# %%
df[['smoker','charges']].groupby(['smoker']).agg(["mean","max","min"]).plot.bar()

# %%
df[['sex','charges']].groupby(['sex']).agg(["mean","max","min"])
# Out:
#              charges
#                 mean          max        min
# sex
# female  12569.578844  63770.42801  1607.5101
# male    13956.751178  62592.87309  1121.8739

# %%
df[['sex','charges']].groupby(['sex']).agg(["mean","max","min"]).plot.bar()

# %%
df[['bmi','charges']].groupby(['bmi']).agg(["mean","max","min"])
# Out:
#              charges
#                 mean          max          min
# bmi
# 15.960   1694.796400   1694.79640   1694.79640
# 16.815   4904.000350   6640.54485   3167.45585
# 17.195  14455.644050  14455.64405  14455.64405
# 17.290   7813.353433  12829.45510   3732.62510
# 17.385   2775.192150   2775.19215   2775.19215
# ...              ...          ...          ...
# 48.070   9432.925300   9432.92530   9432.92530
# 49.060  11381.325400  11381.32540  11381.32540
# 50.380   2438.055200   2438.05520   2438.05520
# 52.580  44501.398200  44501.39820  44501.39820
# 53.130   1163.462700   1163.46270   1163.46270
#
# [548 rows x 3 columns]

# %%
df[['age','charges']].groupby(['age']).agg(["mean","max","min"])
# Out:
#           charges
#              mean          max          min
# age
# 18    7086.217556  38792.68560   1121.87390
# 19    9747.909335  39722.74620   1241.56500
# 20   10159.697736  38344.56600   1391.52870
# 21    4730.464330  26018.95052   1515.34490
# 22   10012.932802  44501.39820   1664.99960
# 23   12419.820040  40904.19950   1815.87590
# 24   10648.015962  38126.24650   1969.61400
# 25    9838.365311  42112.23560   2137.65360
# 26    6133.825309  36085.21900   2302.30000
# 27   12184.701721  39611.75770   2483.73600
# 28    9069.187564  51194.55914   2689.49540
# 29   10430.158727  44585.45587   2866.09100
# 30   12719.110358  40932.42950   3554.20300
# 31   10196.980573  58571.07448   3260.19900
# 32    9220.300291  37607.52770   3866.85520
# 33   12351.532987  55135.40209   3704.35450
# 34   11613.528121  43943.87610   3935.17990
# 35   11307.182031  39983.42595   4746.34400
# 36   12204.476138  43753.33705   4399.73100
# 37   18019.911877  46113.51100   4646.75900
# ...

# %%
df[['children','charges']].groupby(['children']).agg(["mean","max","min"])
# Out:
#                charges
#                   mean          max        min
# children
# 0         12365.975602  63770.42801  1121.8739
# 1         12731.171832  58571.07448  1711.0268
# 2         15073.563734  49577.66240  2304.0022
# 3         15355.318367  60021.39897  3443.0640
# 4         13850.656311  40182.24600  4504.6624
# 5          8786.035247  19023.26000  4687.7970

# %%
df[['region','charges']].groupby(['region']).agg(["mean","max","min"])
# Out:
#                 charges
#                    mean          max        min
# region
# northeast  13406.384516  58571.07448  1694.7964
# northwest  12417.575374  60021.39897  1621.3402
# southeast  14735.411438  63770.42801  1121.8739
# southwest  12346.937377  52590.82939  1241.5650

# %%
df[['age','charges']].plot.scatter(x="age",y="charges", c = "green")

# %%
df[['bmi','charges']].plot.scatter(x="bmi",y="charges", c = "green")

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Import Data
df = pd.read_csv("insurance_regression (1).csv")

# Create Fig and gridspec
fig = plt.figure(figsize=(16, 10), dpi= 80)
grid = plt.GridSpec(4, 4, hspace=0.5, wspace=0.2)

# Define the axes
ax_main = fig.add_subplot(grid[:-1, :-1])
ax_right = fig.add_subplot(grid[:-1, -1], xticklabels=[], yticklabels=[])
ax_bottom = fig.add_subplot(grid[-1, 0:-1], xticklabels=[], yticklabels=[])

# Scatterplot on main ax
ax_main.scatter('age', 'charges', s=df.age, c=df.charges.astype('category').cat.codes, alpha=.9, data=df, cmap="Set1", edgecolors='black', linewidths=.5)

# Add a graph in each part
sns.boxplot(df.age, ax=ax_right, orient="v")
sns.boxplot(df.charges, ax=ax_bottom, orient="h")

# Decorations ------------------
# Remove x axis name for the boxplot
ax_bottom.set(xlabel='')
ax_right.set(ylabel='')

# Main Title, Xlabel and YLabel
ax_main.set(title='Scatterplot with boxplot \n Age and Insurance Charges', xlabel='age', ylabel='charges')

# Set font size of different components
ax_main.title.set_fontsize(20)
for item in ([ax_main.xaxis.label, ax_main.yaxis.label] + ax_main.get_xticklabels() + ax_main.get_yticklabels()):
    item.set_fontsize(14)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_core.py:1303: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
